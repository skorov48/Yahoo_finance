# %% [markdown]
# <a href="https://colab.research.google.com/github/skorov48/Yahoo_finance/blob/main/yahoo_finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import yfinance as yf

# Задаем интервал времени, за который хотим получить данные
start_date = '2025-01-01'
end_date = '2025-02-25'

# Получаем данные о котировках NKE за указанный период
ticker = 'NKE'
data = yf.download(ticker, start=start_date, end=end_date)

# Выводим первые 5 строк полученных данных
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            NKE        NKE        NKE        NKE       NKE
# Date
# 2025-01-02  73.669998  76.690002  73.239998  76.250000  10883400
# 2025-01-03  73.309998  74.190002  73.010002  73.919998  10083500
# 2025-01-06  72.000000  74.320000  71.970001  73.750000  14947300
# 2025-01-07  72.089996  73.440002  71.980003  72.400002  10463500
# 2025-01-08  71.290001  71.820000  71.010002  71.559998  11855000

# %%
import yfinance as yf

# Задаем интервал времени, за который хотим получить данные
start_date = '2025-02-01'
end_date = '2025-03-31'

# Получаем данные о котировках AAPL за указанный период
ticker = 'AAPL'
data = yf.download(ticker, start=start_date, end=end_date)

# Выводим первые 5 строк полученных данных
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-02-03  227.759583  231.575395  225.452122  229.737419  73063300
# 2025-02-04  232.544327  232.873966  226.401072  227.000419  45067300
# 2025-02-05  232.214691  232.414468  228.019307  228.279016  39620300
# 2025-02-06  232.963867  233.543232  230.176923  231.035979  29925300
# 2025-02-07  227.380005  233.743004  227.010401  232.344548  39707200

# %%
import yfinance as yf
import pandas as pd

symbol = "AAPL"
start_date = "2025-01-01"
end_date = "2025-02-25"

# Получаем данные о котировках
ticker_data = yf.Ticker(symbol)
df = ticker_data.history(start=start_date, end=end_date)

# Выводим данные о цене закрытия акций
print(df["Close"])
# Out:
# Date
# 2025-01-02 00:00:00-05:00    243.582199
# 2025-01-03 00:00:00-05:00    243.092728
# 2025-01-06 00:00:00-05:00    244.730927
# 2025-01-07 00:00:00-05:00    241.944000
# 2025-01-08 00:00:00-05:00    242.433441
# 2025-01-10 00:00:00-05:00    236.589874
# 2025-01-13 00:00:00-05:00    234.142563
# 2025-01-14 00:00:00-05:00    233.023788
# 2025-01-15 00:00:00-05:00    237.608749
# 2025-01-16 00:00:00-05:00    228.009308
# 2025-01-17 00:00:00-05:00    229.727417
# 2025-01-21 00:00:00-05:00    222.395477
# 2025-01-22 00:00:00-05:00    223.584167
# 2025-01-23 00:00:00-05:00    223.414368
# 2025-01-24 00:00:00-05:00    222.535324
# 2025-01-27 00:00:00-05:00    229.607544
# 2025-01-28 00:00:00-05:00    237.998322
# 2025-01-29 00:00:00-05:00    239.097122
# 2025-01-30 00:00:00-05:00    237.329056
# 2025-01-31 00:00:00-05:00    235.740814
# 2025-02-03 00:00:00-05:00    227.759583
# 2025-02-04 00:00:00-05:00    232.544327
# 2025-02-05 00:00:00-05:00    232.214691
# 2025-02-06 00:00:00-05:00    232.963867
# 2025-02-07 00:00:00-05:00    227.380005
# 2025-02-10 00:00:00-05:00    227.649994
# 2025-02-11 00:00:00-05:00    232.619995
# 2025-02-12 00:00:00-05:00    236.869995
# 2025-02-13 00:00:00-05:00    241.529999
# 2025-02-14 00:00:00-05:00    244.600006
# 2025-02-18 00:00:00-05:00    244.470001
# 2025-02-19 00:00:00-05:00    244.869995
# 2025-02-20 00:00:00-05:00    245.830002
# 2025-02-21 00:00:00-05:00    245.550003
# 2025-02-24 00:00:00-05:00    247.100006
# Name: Close, dtype: float64

# %% [markdown]
# Документация Yahoo Finance API содержит полный список методов и параметров, которые можно использовать для получения данных о финансовом рынке. Некоторые из основных методов API включают:
#
# Ticker(symbol) - создает объект, который содержит данные о компании, связанной с указанным символом. Например, Ticker("AAPL") создаст объект, содержащий данные об Apple Inc.
#
# history(start=None, end=None, interval="1d", actions=True, auto_adjust=True) - возвращает исторические данные о котировках акций для указанного периода. Метод принимает параметры start и end для задания начальной и конечной даты периода, параметр interval для задания интервала (1d, 1wk, 1mo), параметр actions для включения/отключения данных о дивидендах и слияниях компаний, параметр auto_adjust для автоматической корректировки цен при слияниях и дивидендах.
#
# info - возвращает информацию о компании, связанной с текущим объектом Ticker.
#
# financials - возвращает финансовые показатели компании.
#
# recommendations - возвращает список рекомендаций аналитиков по акциям компании.
#
# calendar - возвращает календарь событий, связанных с компанией, таких как отчеты о прибыли, конференции для инвесторов и т.д.
#
# news - возвращает список новостей, связанных с компанией.
#
# options - возвращает информацию о опционах на акции компании.

# %% [markdown]
# Для работы с API необходимо использовать ключ API, который можно получить после регистрации на сайте Yahoo Finance. Ключ API можно использовать для доступа к различным методам API и получения данных в формате JSON или CSV.
#
# Некоторые из ограничений использования Yahoo Finance API включают:
#
# Ограниченная пропускная способность. Yahoo Finance API может ограничивать количество запросов, которые можно отправлять за определенный период времени.
#
# Ограничения на коммерческое использование. Yahoo Finance API не может использоваться для коммерческих целей без предварительного разрешения.
#
# Ограничения на использование в продуктах, конкурирующих с продуктами Yahoo Finance. Yahoo Finance API не может использоваться в продуктах, которые конкурируют с продуктами Yahoo Finance без предварительного разрешения.
#
# В целом, использование Yahoo Finance API в Python позволяет получать доступ к богатому набору данных о финансовом рынке и использовать их для анализа и принятия решений в области инвестирования и финансов.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Создание объекта Ticker для заданной компании
aapl = yf.Ticker("AAPL")

# Получение цены закрытия акций за последний год
hist = aapl.history(period="1y")

# Рассчет скользящего среднего за 30 дней
hist["SMA_90"] = hist["Close"].rolling(window=30).mean()

# Вывод графика цены закрытия акций и скользящего среднего за последний год
plt.plot(hist["Close"])
plt.plot(hist["SMA_90"])
plt.legend(["Close", "SMA_90"])
plt.show()

# %%
import yfinance as yf
import pandas as pd

# Создание объектов Ticker для двух компаний
nke = yf.Ticker("NKE")
aapl = yf.Ticker("AAPL")

# Получение цены закрытия акций за последний год
nke_hist = nke.history(period="1y")
aapl_hist = aapl.history(period="1y")

# Объединение данных в одну таблицу
data = pd.concat([nke_hist["Close"], aapl_hist["Close"]], axis=1)
data.columns = ["NKE", "AAPL"]

# Рассчет корреляции между ценами акций двух компаний
corr = data.corr()

# Вывод матрицы корреляции
print(corr)
# Out:
#            NKE      AAPL
# NKE   1.000000 -0.783294
# AAPL -0.783294  1.000000

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Создание объекта Ticker для заданной компании
aapl = yf.Ticker("AAPL")

# Получение цены закрытия акций за последние 5 лет
hist = aapl.history(period="5y")

# Рассчет процентного изменения цены закрытия акций
hist["Pct_Change"] = hist["Close"].pct_change()

# Вывод графика процентного изменения цены закрытия акций
plt.plot(hist["Pct_Change"])
plt.title("AAPL Percent Change")
plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Создание объекта Ticker для заданной компании
nke = yf.Ticker("NKE")

# Получение цены закрытия акций за последние 5 лет
hist = nke.history(period="5y")

# Рассчет волатильности цены закрытия акций за 30 дней
hist["Volatility"] = hist["Close"].rolling(window=30).std()

# Вывод графика волатильности цены закрытия акций
plt.plot(hist["Volatility"])
plt.title("NKE Volatility")
plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Создание объектов Ticker для заданных компаний
nke = yf.Ticker("NKE")
aapl = yf.Ticker("AAPL")

# Получение цены закрытия акций за последние 5 лет
nke_hist = nke.history(period="5y")
aapl_hist = aapl.history(period="5y")

# Объединение таблиц цен закрытия акций для обеих компаний
merged = pd.merge(nke_hist["Close"], aapl_hist["Close"], left_index=True, right_index=True, suffixes=("_NKE", "_AAPL"))

# Вывод графиков цен закрытия акций обеих компаний
merged.plot()
plt.title("NKE vs AAPL Close Prices")
plt.show()

# Рассчет коэффициента корреляции между ценами закрытия акций обеих компаний
corr = merged.corr().iloc[0,1]

# Вывод коэффициента корреляции
print("NKE vs AAPL Correlation: {:.2f}".format(corr))
# Out:
# NKE vs AAPL Correlation: -0.27

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Задание тикеров двух компаний
ticker1 = "NKE"
ticker2 = "AAPL"

# Получение цен закрытия за заданный период времени для двух компаний
start_date = "2025-01-01"
end_date = "2025-02-25"
stock1 = yf.Ticker(ticker1)
stock2 = yf.Ticker(ticker2)
stock1_hist = stock1.history(start=start_date, end=end_date)
stock2_hist = stock2.history(start=start_date, end=end_date)

# Создание DataFrame из цен закрытия для двух компаний
df = pd.concat([stock1_hist["Close"], stock2_hist["Close"]], axis=1)
df.columns = [ticker1, ticker2]

# Рассчет дневных доходностей для двух компаний
df_returns = df.pct_change()

# Рассчет корреляции между доходностями двух компаний
corr = df_returns.corr().iloc[0,1]

# Построение scatter plot
plt.scatter(df_returns[ticker1], df_returns[ticker2])
plt.title(f"{ticker1} vs {ticker2} - Correlation: {corr:.2f}")
plt.xlabel(f"{ticker1} Returns")
plt.ylabel(f"{ticker2} Returns")
plt.show()

# %% [markdown]
# # Google Таблицы
# В примерах ниже для взаимодействия с Google Таблицами используется библиотека gspread с открытым исходным кодом.

# %% [markdown]
# Импортируйте библиотеку, выполните аутентификацию и установите связь с Таблицами.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-134464509616> in <cell line: 0>()
#       1 from google.colab import auth
# ----> 2 auth.authenticate_user()
#       3
#       4 import gspread
#       5 from google.auth import default
#
# /usr/local/lib/python3.11/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     258   if not _check_adc(_CredentialType.USER):
#     259     if use_auth_ephem:
# --> 260       _message.blocking_request(
#     261           'request_auth',
#     262           request={'authType': 'auth_user_ephemeral'},
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
